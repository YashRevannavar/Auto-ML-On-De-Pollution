# %% [markdown]
# # Auto-ML 04 with pycaret

# %%
# %reset -f
import pandas as pd
from pycaret.regression import *

# %%
df = pd.read_csv("../Data/cleanned/zusammen.csv", parse_dates=["date"])
df.drop(columns=["rohwert"], inplace=True)
df.dropna(inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#                      date  wert  temp  dwpt  rhum  prcp
# 0     2020-01-02 00:00:00    36   1.0  -0.6  89.0   0.0
# 1     2020-01-02 07:00:00    31   0.1  -1.2  91.0   0.0
# 2     2020-01-02 06:00:00    32  -0.3  -1.3  93.0   0.0
# 3     2020-01-02 05:00:00    27  -0.5  -1.2  95.0   0.0
# 4     2020-01-02 04:00:00    38  -0.4  -0.8  97.0   0.0
# ...                   ...   ...   ...   ...   ...   ...
# 23731 2022-09-30 20:00:00    27  12.9   7.3  69.0   0.0
# 23732 2022-09-30 21:00:00    30  13.1   7.3  68.0   0.0
# 23733 2022-09-30 22:00:00    37  12.7   7.6  71.0   0.0
# 23734 2022-09-30 23:00:00    27  12.6   7.5  71.0   0.0
# 23735 2022-10-01 00:00:00    30  12.7   7.8  72.0   0.0
#
# [23736 rows x 6 columns]

# %%
s = setup(df, target = 'wert', session_id = 123)
# Out:
# <style  type="text/css" >
# #T_e84f2e82_4361_11ee_9df3_3ceceffcdd3arow40_col1,#T_e84f2e82_4361_11ee_9df3_3ceceffcdd3arow43_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_e84f2e82_4361_11ee_9df3_3ceceffcdd3a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e84f2e82_4361_11ee_9df3_3ceceffcdd3alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e84f2e82_4361_11ee_9df3_3ceceffcdd3arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e84f2e82_4361_11ee_9df3_3ceceffcdd3arow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_e84f2e82_4361_11ee_9df3_3ceceffcdd3alevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
best = s.compare_models()
# Out:
# <style  type="text/css" >
#     #T_b115b260_4366_11ee_9df3_3ceceffcdd3a th {
#           text-align: left;
# ...

# %%
print(best)
# Out:
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       float_dtype='float32', id_columns=[],
#                                       ml_usecase='regression',
#                                       numerical_features=[], target='wert',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical='not_available',
#                                 fill_value_n...
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
#                  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse',
# ...

# %%
s.save_model(best, '../models/aml-pycaret-03/aml-pycaret-03')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        float_dtype='float32', id_columns=[],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='wert',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical='not_available',
#                                  fill_value_n...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=None,
# ...

# %%
best = load_model('../models/aml-pycaret-03/aml-pycaret-03')
print(best)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       float_dtype='float32', id_columns=[],
#                                       ml_usecase='regression',
#                                       numerical_features=[], target='wert',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical='not_available',
#                                 fill_value_n...
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
# ...

# %%
predict = sb.predict_model(best)
# Out:
# <style  type="text/css" >
# </style><table id="T_c278ceb6_4366_11ee_9df3_3ceceffcdd3a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c278ceb6_4366_11ee_9df3_3ceceffcdd3alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c278ceb6_4366_11ee_9df3_3ceceffcdd3arow0_col0" class="data row0 col0" >Random Forest Regressor</td>
#                         <td id="T_c278ceb6_4366_11ee_9df3_3ceceffcdd3arow0_col1" class="data row0 col1" >5.8583</td>
# ...

# %%
predict.columns
# Out:
# Index(['temp', 'dwpt', 'rhum', 'prcp', 'date_month_1', 'date_month_10',
#        'date_month_11', 'date_month_12', 'date_month_2', 'date_month_3',
#        'date_month_4', 'date_month_5', 'date_month_6', 'date_month_7',
#        'date_month_8', 'date_month_9', 'date_weekday_0', 'date_weekday_1',
#        'date_weekday_2', 'date_weekday_3', 'date_weekday_4', 'date_weekday_5',
#        'date_weekday_6', 'date_is_month_end_0', 'date_is_month_start_1',
#        'date_hour_0', 'date_hour_1', 'date_hour_10', 'date_hour_11',
#        'date_hour_12', 'date_hour_13', 'date_hour_14', 'date_hour_15',
#        'date_hour_16', 'date_hour_17', 'date_hour_18', 'date_hour_19',
#        'date_hour_2', 'date_hour_20', 'date_hour_21', 'date_hour_22',
#        'date_hour_23', 'date_hour_3', 'date_hour_4', 'date_hour_5',
#        'date_hour_6', 'date_hour_7', 'date_hour_8', 'date_hour_9', 'wert',
#        'Label'],
#       dtype='object')
